# %%
import re
import math
import datetime
import csv

# %%
def parse_file_content(filename):
  with open(filename, 'r') as file:
        content = file.read()
  segments = []
  for segment in content.split('\n\n'):
    lines = segment.split('\n')
    if len(lines) >= 3:
        # Extract time and speaker
        times = re.findall(r'\d+:\d\d:\d\d\.\d+', lines[1])
        if len(times) == 2:
          start_time = times[0]
          end_time = times[1]
          speaker = lines[2].split(':')[0]
          text = lines[2].split(':')[1]
          segments.append(( start_time,end_time,  speaker, text))
  return segments


def parse_timestamp(timestamp_str):
    timestamp_str = timestamp_str.strip().replace('.', ',')
    return datetime.datetime.strptime(timestamp_str, '%H:%M:%S,%f')

def calculate_features(segments):
    turn_switches = 0

    #patient features
    pat_sp_count = pat_lp_count = 0
    total_pat_word_count = 0
    total_pat_sp_duration = total_pat_lp_duration = datetime.timedelta()
    total_pat_duration = datetime.timedelta()
    ga_pi_count = 0
    total_ga_pi_duration = datetime.timedelta()
    pat_turn_count = 0
    total_pat_turn_word_count = 0

    #interviewer features
    int_sp_count = int_lp_count = 0
    total_int_sp_duration = total_int_lp_duration = datetime.timedelta()
    total_int_word_count = 0
    total_int_duration = datetime.timedelta()
    ga_ip_count = 0
    total_ga_ip_duration = datetime.timedelta()
    int_turn_count = 0
    total_int_turn_word_count = 0
    la_count = ga_count = 0
    total_la_duration = total_ga_duration = datetime.timedelta()
    last_end_time = parse_timestamp(segments[0][1])
    last_speaker = segments[0][2]
    for start_str, end_str, speaker, text in segments:
        start_time = parse_timestamp(start_str)
        end_time = parse_timestamp(end_str)
        words = len(text.split())
        silence_duration = (start_time - last_end_time)
        if speaker == "PAT":
            total_pat_duration += (start_time - end_time)
            total_pat_word_count += words
        if speaker == "INT":
            total_int_duration += (start_time - end_time)
            total_int_word_count += words
        if last_speaker != speaker:
            turn_switches += 1
            if silence_duration.total_seconds() >= 1.5:
                la_count += 1
                total_la_duration += silence_duration
            elif silence_duration.total_seconds() >= 0.5:
                ga_count += 1
                total_ga_duration += silence_duration
                if last_speaker == "PAT":
                    ga_pi_count += 1
                    total_ga_pi_duration += silence_duration
                else:
                    ga_ip_count += 1
                    total_ga_ip_duration += silence_duration
        elif (last_speaker == speaker and speaker=="PAT"):
            pat_turn_count += 1
            total_pat_turn_word_count += words
            if silence_duration.total_seconds() >= 1.5:
                pat_lp_count += 1
                total_pat_lp_duration += silence_duration
            elif silence_duration.total_seconds() >= 0.5:
                pat_sp_count += 1
                total_pat_sp_duration += silence_duration
        elif (last_speaker == speaker and speaker=="INT"):
            int_turn_count += 1
            total_int_turn_word_count += words
            if silence_duration.total_seconds() > 1.5:
                int_lp_count += 1
                total_int_lp_duration += silence_duration
            elif silence_duration.total_seconds() > 5:
                int_sp_count += 1
                total_int_sp_duration += silence_duration
        last_end_time = end_time
        last_speaker = speaker

    # Normalize durations by total speaking time
    total_duration_seconds = (last_end_time - parse_timestamp(segments[0][0])).total_seconds()
    normalized_la_duration = total_la_duration.total_seconds() / total_duration_seconds if total_duration_seconds else 0
    normalized_ga_duration = total_ga_duration.total_seconds() / total_duration_seconds if total_duration_seconds else 0

    # Calculate turn switches per minute
    total_duration_minutes = total_duration_seconds / 60
    turn_switches_per_minute = turn_switches / total_duration_minutes if total_duration_minutes else 0

    #Calculate Patient features
    pat_sp_count = pat_sp_count / total_pat_word_count
    pat_lp_count = pat_lp_count / total_pat_word_count
    normalized_pat_sp_duration = total_pat_sp_duration.total_seconds() / total_pat_duration.total_seconds()  if total_pat_duration else 0
    normalized_pat_lp_duration = total_pat_lp_duration.total_seconds() / total_pat_duration.total_seconds()  if total_pat_duration else 0
    gap_pi_count = ga_pi_count / turn_switches if turn_switches else 0
    normalized_ga_pi_duration = total_ga_pi_duration.total_seconds() / gap_pi_count if gap_pi_count else 0
    standardized_pause_rate =  total_pat_word_count / (pat_sp_count + pat_lp_count) if  (pat_sp_count + pat_lp_count) else 0
    standardized_phonation_time =  total_pat_word_count / total_pat_duration.total_seconds() if total_pat_duration else 0
    phonation_rate = total_pat_duration.total_seconds() +  total_pat_sp_duration.total_seconds() + total_pat_lp_duration.total_seconds()
    if phonation_rate == 0:
        transformed_phonation_rate = 0
    else:
        ratio = total_pat_word_count / phonation_rate
        if ratio >= 0:  # Ensure non-negative input for sqrt
            sqrt_ratio = math.sqrt(ratio)
            if -1 <= sqrt_ratio <= 1:  # Ensure input is within [-1, 1] for asin
                transformed_phonation_rate = math.asin(sqrt_ratio)
            else:
                transformed_phonation_rate = 0
        else:
            transformed_phonation_rate = 0

    floor_control_ratio = total_duration_seconds / total_pat_duration.total_seconds() if total_pat_duration else 0
    pat_turn_length =   total_pat_turn_word_count/pat_turn_count if pat_turn_count else 0

    #Calculate interviewer features
    int_sp_count = int_sp_count / total_int_word_count if total_int_word_count else 0
    int_lp_count = int_lp_count / total_int_word_count if total_int_word_count else 0
    normalized_int_sp_duration = total_int_sp_duration.total_seconds() / total_int_duration.total_seconds()  if total_int_duration else 0
    normalized_int_lp_duration = total_int_lp_duration.total_seconds() / total_int_duration.total_seconds()  if total_int_duration else 0
    gap_ip_count = ga_ip_count / turn_switches if turn_switches else 0
    normalized_ga_ip_duration = total_ga_ip_duration.total_seconds() / gap_ip_count if gap_ip_count else 0
    int_turn_length =   total_int_turn_word_count/int_turn_count if int_turn_count else 0
    # Return features
    return {
        'LA': la_count,
        'Dur_LA': normalized_la_duration,
        'GA': ga_count,
        'Dur_GA': normalized_ga_duration,
        'Turn_switches_per_Minute': turn_switches_per_minute,
        'PAT_SP': pat_sp_count,
        'PAT_LP': pat_lp_count,
        'Dur_PAT_SP': normalized_pat_sp_duration,
        'Dur_PAT_LP': normalized_pat_lp_duration,
        'GA_PI': ga_pi_count,
        'Dur_GA_PI': normalized_ga_pi_duration,
        'SPR': standardized_pause_rate,
        'SPT': standardized_phonation_time,
        'TPR': transformed_phonation_rate,
        'FCR': floor_control_ratio,
        'PAT_TL': pat_turn_length,
        #int features 7
        'INT_SP': pat_sp_count,
        'INT_LP': pat_lp_count,
        'Dur_INT_SP': normalized_int_sp_duration,
      'Dur_INT_LP': normalized_int_lp_duration,
        'GA_IP': ga_ip_count,
        'Dur_GA_IP': normalized_ga_ip_duration,
        'INT_TL': int_turn_length,

    }

def process_srt_to_csv(srt_path, csv_path):
    segments = parse_file_content(srt_path)
    features = calculate_features(segments)
    audio_name = srt_path.split('/')[-1].replace('.srt', '')

    with open(csv_path, 'w', newline='') as csvfile:
        # Use the keys from the features dictionary as fieldnames
        fieldnames = list(features.keys()) + ['Audio_File']
        csvwriter = csv.DictWriter(csvfile, fieldnames=fieldnames)
        csvwriter.writeheader()

        # Add the audio file name to the features dictionary
        features['Audio_File'] = audio_name

        # Write the dictionary to the CSV file
        csvwriter.writerow(features)

# %% [markdown]
# # **Generate CSV File**

# %%
import os
import csv
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
directory_path = '/content/drive/MyDrive/FYPRepository'
csv_path = os.path.join(directory_path, 'all_interactional_features.csv')
if not os.path.isfile(csv_path):
    with open(csv_path, 'w') as f:
        pass

# %%
output_dir = "/content/drive/MyDrive/FYPRepository/Transcripts"
csv_path = '/content/drive/MyDrive/FYPRepository/all_interactional_features.csv'
fieldnames = None  # This should be initialized outside the for-loop

# Open the CSV file once outside the loop
with open(csv_path, 'a', newline='') as csvfile:
    csvwriter = None  # Initialize the CSV writer variable

    for subfolder in os.listdir(output_dir):
        subfolder_path = os.path.join(output_dir, subfolder)
        if os.path.isdir(subfolder_path):
            for filename in os.listdir(subfolder_path):
                print(subfolder,filename)
                if filename.endswith(".srt"):
                    srt_path = os.path.join(subfolder_path, filename)
                    segments = parse_file_content(srt_path)
                    if len(segments) > 0:
                      features = calculate_features(segments)
                      audio_name = filename.replace('.srt', '')
                      if fieldnames is None:
                          # Use the keys from the first features dictionary as fieldnames
                          fieldnames = list(features.keys()) + ['Audio_File']
                          csvwriter = csv.DictWriter(csvfile, fieldnames=fieldnames)
                          csvwriter.writeheader()
                      # Add the audio file name to the features dictionary
                      features['Audio_File'] = audio_name
                      # Write the dictionary to the CSV file as a new row
                      csvwriter.writerow(features)
# Out:
# English S154.srt
# English S156.srt
# English S153.srt
# English S151.srt
# English S150.srt
# English S149.srt
# English S144.srt
# English S139.srt
# English S138.srt
# English S142.srt
# English S143.srt
# English S148.srt
# English S141.srt
# English S145.srt
# English S126.srt
# English S128.srt
# English S132.srt
# English S125.srt
# English S129.srt
# English S136.srt
# English S127.srt
# English S130.srt
# English S137.srt
# English S135.srt
# English S111.srt
# English S110.srt
# English S114.srt
# English S118.srt
# English S108.srt
# English S107.srt
# English S124.srt
# English S122.srt
# English S104.srt
# English S116.srt
# English S093.srt
# English S096.srt
# English S092.srt
# English S094.srt
# English S095.srt
# English S100.srt
# English S103.srt
# English S090.srt
# English S101.srt
# English S097.srt
# English S086.srt
# English S087.srt
# English S079.srt
# English S084.srt
# English S083.srt
# English S081.srt
# English S140.srt
# English S082.srt
# English S089.srt
# English S080.srt
# English S073.srt
# English S072.srt
# English S076.srt
# English S077.srt
# English S058.srt
# English S062.srt
# English S063.srt
# English S070.srt
# English S064.srt
# English S056.srt
# English S061.srt
# English S059.srt
# English S067.srt
# English S068.srt
# English S039.srt
# English S041.srt
# English S055.srt
# English S038.srt
# English S052.srt
# English S051.srt
# English S048.srt
# English S043.srt
# English S040.srt
# English S049.srt
# English S033.srt
# English S030.srt
# English S025.srt
# English S028.srt
# English S035.srt
# English S032.srt
# English S027.srt
# English S036.srt
# English S034.srt
# English S029.srt
# English S021.srt
# English S019.srt
# English S015.srt
# English S012.srt
# English S016.srt
# English S018.srt
# English S013.srt
# English S020.srt
# English S017.srt
# English S024.srt
# English S005.srt
# English S002.srt
# English S007.srt
# English S003.srt
# English S009.srt
# English S001.srt
# English S011.srt
# English S006.srt
# English S004.srt
# English S071.srt
# English adrso004.srt
# English adrso009.srt
# English adrso003.srt
# English adrso007.srt
# English adrso002.srt
# English adrso008.srt
# English adrso006.srt
# English adrso005.srt
# English adrso011.srt
# English adrso013.srt
# English adrso017.srt
# English adrso016.srt
# English adrso010.srt
# English adrso012.srt
# English adrso019.srt
# English adrso014.srt
# English adrso015.srt
# English adrso018.srt
# English adrso023.srt
# English adrso028.srt
# English adrso020.srt
# English adrso029.srt
# English adrso031.srt
# English adrso024.srt
# English adrso025.srt
# English adrso021.srt
# English adrso027.srt
# English adrso022.srt
# English adrso036.srt
# English adrso035.srt
# English adrso032.srt
# English adrso043.srt
# English adrso039.srt
# English adrso042.srt
# English adrso037.srt
# English adrso033.srt
# English adrso038.srt
# English adrso041.srt
# English adrso047.srt
# English adrso054.srt
# English adrso045.srt
# English adrso044.srt
# English adrso046.srt
# English adrso049.srt
# English adrso052.srt
# English adrso053.srt
# English adrso056.srt
# English adrso055.srt
# English adrso060.srt
# English adrso059.srt
# English adrso066.srt
# English adrso062.srt
# English adrso063.srt
# English adrso070.srt
# English adrso064.srt
# English adrso065.srt
# English adrso071.srt
# English adrso068.srt
# English adrso083.srt
# English adrso075.srt
# English adrso092.srt
# English adrso074.srt
# English adrso088.srt
# English adrso072.srt
# English adrso093.srt
# English adrso078.srt
# English adrso077.srt
# English adrso090.srt
# English adrso116.srt
# English adrso117.srt
# English adrso109.srt
# English adrso098.srt
# English adrso099.srt
# English adrso108.srt
# English adrso106.srt
# English adrso113.srt
# English adrso112.srt
# English adrso110.srt
# English adrso122.srt
# English adrso123.srt
# English adrso130.srt
# English adrso121.srt
# English adrso125.srt
# English adrso132.srt
# English adrso124.srt
# English adrso126.srt
# English adrso128.srt
# English adrso118.srt
# English adrso149.srt
# English adrso142.srt
# English adrso148.srt
# English adrso138.srt
# English adrso134.srt
# English adrso141.srt
# English adrso135.srt
# English adrso150.srt
# English adrso144.srt
# English adrso140.srt
# English adrso156.srt
# English adrso160.srt
# English adrso151.srt
# English adrso159.srt
# English adrso152.srt
# English adrso155.srt
# English adrso153.srt
# English adrso157.srt
# English adrso158.srt
# English adrso154.srt
# English adrso169.srt
# English adrso170.srt
# English adrso161.srt
# English adrso166.srt
# English adrso164.srt
# English adrso171.srt
# English adrso167.srt
# English adrso168.srt
# English adrso162.srt
# English adrso165.srt
# English adrso184.srt
# English adrso177.srt
# English adrso182.srt
# English adrso173.srt
# English adrso180.srt
# English adrso181.srt
# English adrso178.srt
# English adrso183.srt
# English adrso179.srt
# English adrso172.srt
# English adrso188.srt
# English adrso194.srt
# English adrso197.srt
# English adrso190.srt
# English adrso198.srt
# English adrso186.srt
# English adrso192.srt
# English adrso189.srt
# English adrso187.srt
# English adrso185.srt
# English adrso202.srt
# English adrso210.srt
# English adrso212.srt
# English adrso206.srt
# English adrso209.srt
# English adrso211.srt
# English adrso200.srt
# English adrso214.srt
# English adrso205.srt
# English adrso199.srt
# English adrso219.srt
# English adrso223.srt
# English adrso226.srt
# English adrso222.srt
# English adrso218.srt
# English adrso215.srt
# English adrso220.srt
# English adrso217.srt
# English adrso224.srt
# English adrso216.srt
# English adrso228.srt
# English adrso243.srt
# English adrso229.srt
# English adrso233.srt
# English adrso235.srt
# English adrso236.srt
# English adrso237.srt
# English adrso231.srt
# English adrso232.srt
# English adrso234.srt
# English adrso246.srt
# English adrso250.srt
# English adrso248.srt
# English adrso251.srt
# English adrso245.srt
# English adrso253.srt
# English adrso254.srt
# English adrso244.srt
# English adrso249.srt
# English adrso247.srt
# English adrso259.srt
# English adrso262.srt
# English adrso256.srt
# English adrso263.srt
# English adrso258.srt
# English adrso257.srt
# English adrso255.srt
# English adrso264.srt
# English adrso261.srt
# English adrso260.srt
# English adrso272.srt
# English adrso275.srt
# English adrso274.srt
# English adrso269.srt
# English adrso268.srt
# English adrso267.srt
# English adrso265.srt
# English adrso266.srt
# English adrso273.srt
# English adrso270.srt
# English adrso276.srt
# English adrso285.srt
# English adrso281.srt
# English adrso278.srt
# English adrso283.srt
# English adrso279.srt
# English adrso284.srt
# English adrso286.srt
# English adrso277.srt
# English adrso280.srt
# English adrso296.srt
# English adrso292.srt
# English adrso287.srt
# English adrso291.srt
# English adrso293.srt
# English adrso290.srt
# English adrso295.srt
# English adrso294.srt
# English adrso288.srt
# English adrso289.srt
# English adrso307.srt
# English adrso308.srt
# English adrso298.srt
# English adrso304.srt
# English adrso300.srt
# English adrso303.srt
# English adrso299.srt
# English adrso297.srt
# English adrso302.srt
# English adrso301.srt
# English adrso313.srt
# English adrso314.srt
# English adrso089.srt
# English adrso316.srt
# English adrso315.srt
# English adrso309.srt
# English adrso310.srt
# English adrso312.srt
# English adrso317.srt
# Greek madrs081.srt
# Greek madrs009.srt
# Greek madrs087.srt
# Greek madrs097.srt
# Greek madrs046.srt
# Greek madrs054.srt
# Greek madrs047.srt
# Greek madrs002.srt
# Spanish MCI-M-71-275.srt
# Spanish MCI-M-75-147.srt
# Spanish MCI-M-80-201.srt
# Spanish MCI-M-72-50.srt
# Spanish MCI-M-68-68.srt
# Spanish MCI-M-66-85.srt
# Spanish MCI-M-70-102.srt
# Spanish MCI-M-71-143.srt
# Spanish MCI-M-76-1.srt
# Spanish MCI-M-70-18.srt
# Spanish MCI-M-87-264.srt
# Spanish MCI-M-83-307.srt
# Spanish MCI-M-86-302.srt
# Spanish MCI-M-84-115.srt
# Spanish MCI-M-81-343.srt
# Spanish MCI-M-88-128.srt
# Spanish MCI-M-86-255.srt
# Spanish MCI-M-82-248.srt
# Spanish MCI-M-86-308.srt
# Spanish MCI-M-81-80.srt
# Spanish MCI-M-89-323.srt
# Spanish MCI-W-62-38.srt
# Spanish MCI-W-59-34.srt
# Spanish MCI-W-65-277.srt
# Spanish MCI-W-51-230.srt
# Spanish MCI-M-89-125.srt
# Spanish MCI-W-64-43.srt
# Spanish MCI-W-50-205.srt
# Spanish MCI-M-90-306.srt
# Spanish MCI-M-90-81.srt
# Spanish MCI-W-66-73.srt
# Spanish MCI-W-69-127.srt
# Spanish MCI-W-67-123.srt
# Spanish MCI-W-67-69.srt
# Spanish MCI-W-72-211.srt
# Spanish MCI-W-69-90.srt
# Spanish MCI-W-67-53.srt
# Spanish MCI-W-67-61.srt
# Spanish MCI-W-80-39.srt
# Spanish MCI-W-67-11.srt
# Spanish MCI-W-69-119.srt
# Spanish MCI-W-79-361.srt
# Spanish MCI-W-76-37.srt
# Spanish MCI-W-76-36.srt
# Spanish MCI-W-80-14.srt
# Spanish MCI-W-74-35.srt
# Spanish MCI-W-78-240.srt
# Spanish MCI-W-73-139.srt
# Spanish MCI-W-80-241.srt
# Spanish MCI-W-76-360.srt
# Spanish MCI-W-81-292.srt
# Spanish MCI-W-81-293.srt
# Spanish MCI-W-80-342.srt
# Spanish MCI-W-81-167.srt
# Spanish MCI-W-82-130.srt
# Spanish MCI-W-82-94.srt
# Spanish MCI-W-82-243.srt
# Spanish MCI-W-81-179.srt
# Spanish MCI-W-81-164.srt
# Spanish MCI-W-81-165.srt
# Spanish MCI-W-83-289.srt
# Spanish MCI-W-84-260.srt
# Spanish MCI-W-86-59.srt
# Spanish MCI-W-84-104.srt
# Spanish MCI-W-85-58.srt
# Spanish MCI-W-83-121.srt
# Spanish MCI-W-84-154.srt
# Spanish MCI-W-85-103.srt
# Spanish MCI-W-85-267.srt
# Spanish MCI-W-89-235.srt
# Spanish MCI-W-85-126.srt
# Spanish MCI-W-89-101.srt
# Spanish MCI-W-88-294.srt
# Spanish MCI-W-90-106.srt
# Spanish MCI-W-87-309.srt
# Spanish MCI-W-88-204.srt
# Spanish MCI-W-87-100.srt
# Spanish MCI-W-86-92.srt
# Spanish MCI-W-86-124.srt
# Spanish MCI-W-94-266.srt
# Spanish MCI-W-87-338.srt
# Spanish MCI-W-96-297.srt
# Spanish MCI-W-92-238.srt
# Spanish MCI-W-91-300.srt
# Spanish MCI-W-91-105.srt
# Spanish MCI-W-90-239.srt
# Spanish MCI-W-90-118.srt
# Spanish MCI-M-72-15.srt
# Spanish MCI-W-90-251.srt
# Spanish HC-M-55-78.srt
# Spanish MCI-W-93-265.srt
# Spanish HC-M-65-48.srt
# Spanish HC-M-62-129.srt
# Spanish HC-M-65-79.srt
# Spanish HC-M-57-233.srt
# Spanish HC-M-65-89.srt
# Spanish HC-M-65-278.srt
# Spanish HC-M-59-291.srt
# Spanish HC-M-68-82.srt
# Spanish HC-M-68-87.srt
# Spanish HC-M-68-96.srt
# Spanish HC-M-66-25.srt
# Spanish HC-M-67-117.srt
# Spanish HC-M-65-348.srt
# Spanish HC-M-67-62.srt
# Spanish HC-M-67-65.srt
# Spanish HC-M-67-84.srt
# Spanish HC-M-71-326.srt
# Spanish HC-M-72-137.srt
# Spanish HC-M-70-131.srt
# Spanish HC-M-70-145.srt
# Spanish HC-M-71-274.srt
# Spanish HC-M-73-5.srt
# Spanish HC-M-72-298.srt
# Spanish HC-M-70-222.srt
# Spanish HC-M-72-67.srt
# Spanish HC-M-80-178.srt
# Spanish HC-M-72-134.srt
# Spanish HC-M-79-345.srt
# Spanish HC-M-74-132.srt
# Spanish HC-M-76-185.srt
# Spanish HC-M-79-218.srt
# Spanish HC-M-80-3.srt
# Spanish HC-M-80-186.srt
# Spanish HC-M-76-328.srt
# Spanish HC-M-73-146.srt
# Spanish HC-M-76-9.srt
# Spanish HC-M-82-158.srt
# Spanish HC-M-81-166.srt
# Spanish HC-M-80-188.srt
# Spanish HC-M-81-175.srt
# Spanish HC-M-82-66.srt
# Spanish HC-M-81-176.srt
# Spanish HC-M-82-236.srt
# Spanish HC-M-82-299.srt
# Spanish HC-M-83-112.srt
# Spanish HC-M-88-109.srt
# Spanish HC-M-88-91.srt
# Spanish HC-M-85-111.srt
# Spanish HC-M-86-12.srt
# Spanish HC-M-89-290.srt
# Spanish HC-M-87-93.srt
# Spanish HC-M-96-257.srt
# Spanish HC-M-84-231.srt
# Spanish HC-M-87-86.srt
# Spanish HC-W-64-273.srt
# Spanish HC-W-65-203.srt
# Spanish HC-W-64-341.srt
# Spanish HC-W-63-198.srt
# Spanish HC-W-54-279.srt
# Spanish HC-W-61-212.srt
# Spanish HC-W-63-7.srt
# Spanish HC-W-58-213.srt
# Spanish HC-W-59-276.srt
# Spanish HC-W-61-353.srt
# Spanish HC-W-67-63.srt
# Spanish HC-W-66-55.srt
# Spanish HC-W-67-327.srt
# Spanish HC-W-67-88.srt
# Spanish HC-W-66-70.srt
# Spanish HC-W-67-17.srt
# Spanish HC-W-67-71.srt
# Spanish HC-W-67-77.srt
# Spanish HC-W-67-60.srt
# Spanish HC-W-67-16.srt
# Spanish HC-W-68-355.srt
# Spanish HC-W-68-113.srt
# Spanish HC-W-68-335.srt
# Spanish HC-W-67-330.srt
# Spanish HC-W-68-74.srt
# Spanish HC-W-68-76.srt
# Spanish HC-W-68-75.srt
# Spanish HC-W-68-346.srt
# Spanish HC-W-68-64.srt
# Spanish HC-W-68-208.srt
# Spanish HC-W-70-220.srt
# Spanish HC-W-70-331.srt
# Spanish HC-W-69-33.srt
# Spanish HC-W-70-116.srt
# Spanish HC-W-69-200.srt
# Spanish HC-W-69-83.srt
# Spanish HC-W-70-199.srt
# Spanish HC-W-70-141.srt
# Spanish HC-W-70-148.srt
# Spanish HC-W-69-4.srt
# Spanish HC-W-70-334.srt
# Spanish HC-W-71-356.srt
# Spanish HC-W-71-336.srt
# Spanish HC-W-71-135.srt
# Spanish HC-W-72-136.srt
# Spanish HC-W-71-151.srt
# Spanish HC-W-73-140.srt
# Spanish HC-W-72-142.srt
# Spanish HC-W-71-149.srt
# Spanish HC-W-72-286.srt
# Spanish HC-W-74-6.srt
# Spanish HC-W-74-150.srt
# Spanish HC-W-74-152.srt
# Spanish HC-W-74-168.srt
# Spanish HC-W-74-32.srt
# Spanish HC-W-73-214.srt
# Spanish HC-W-73-333.srt
# Spanish HC-W-74-28.srt
# Spanish HC-W-73-352.srt
# Spanish HC-W-74-22.srt
# Spanish HC-W-74-215.srt
# Spanish HC-W-76-189.srt
# Spanish HC-W-76-197.srt
# Spanish HC-W-75-349.srt
# Spanish HC-W-74-350.srt
# Spanish HC-W-76-191.srt
# Spanish HC-W-76-23.srt
# Spanish HC-W-76-65.srt
# Spanish HC-W-75-153.srt
# Spanish HC-W-75-144.srt
# Spanish HC-W-76-359.srt
# Spanish HC-W-76-351.srt
# Spanish HC-W-78-8.srt
# Spanish HC-W-78-2.srt
# Spanish HC-W-77-332.srt
# Spanish HC-W-78-10.srt
# Spanish HC-W-77-340.srt
# Spanish HC-W-78-169.srt
# Spanish HC-W-78-170.srt
# Spanish HC-W-78-171.srt
# Spanish HC-W-79-174.srt
# Spanish HC-W-79-177.srt
# Spanish HC-W-79-97.srt
# Spanish HC-W-78-337.srt
# Spanish HC-W-78-192.srt
# Spanish HC-W-79-181.srt
# Spanish HC-W-79-180.srt
# Spanish HC-W-78-217.srt
# Spanish HC-W-78-229.srt
# Spanish HC-W-78-216.srt
# Spanish HC-W-80-173.srt
# Spanish HC-W-81-26.srt
# Spanish HC-W-81-30.srt
# Spanish HC-W-81-190.srt
# Spanish HC-W-81-172.srt
# Spanish HC-W-80-31.srt
# Spanish HC-W-80-72.srt
# Spanish HC-W-80-187.srt
# Spanish HC-W-80-339.srt
# Spanish HC-W-79-228.srt
# Spanish HC-W-82-110.srt
# Spanish HC-W-81-221.srt
# Spanish HC-W-82-219.srt
# Spanish HC-W-81-256.srt
# Spanish HC-W-82-263.srt
# Spanish HC-W-82-95.srt
# Spanish HC-W-82-206.srt
# Spanish HC-W-82-114.srt
# Spanish HC-W-82-288.srt
# Spanish HC-W-81-232.srt
# Spanish HC-W-83-252.srt
# Spanish HC-W-82-347.srt
# Spanish HC-W-83-122.srt
# Spanish HC-W-83-133.srt
# Spanish HC-W-82-329.srt
# Spanish HC-W-83-209.srt
# Spanish HC-W-82-358.srt
# Spanish HC-W-82-362.srt
# Spanish HC-W-83-344.srt
# Spanish HC-W-83-27.srt
# Spanish HC-W-83-357.srt
# Spanish HC-W-84-304.srt
# Spanish HC-W-86-29.srt
# Spanish HC-W-84-138.srt
# Spanish HC-W-84-301.srt
# Spanish HC-W-84-259.srt
# Spanish HC-W-84-107.srt
# Spanish HC-W-85-254.srt
# Spanish HC-W-84-312.srt
# Spanish HC-W-85-108.srt
# Spanish HC-W-86-287.srt
# Spanish HC-W-87-261.srt
# Spanish HC-W-86-253.srt
# Spanish HC-W-87-98.srt
# Spanish HC-W-90-120.srt
# Spanish HC-M-90-295.srt
# Spanish HC-W-86-99.srt
# Spanish HC-W-91-262.srt
# Spanish HC-W-93-296.srt
# Spanish AD-M-69-272.srt
# Spanish AD-M-67-285.srt
# Spanish AD-M-57-163.srt
# Spanish AD-M-65-40.srt
# Spanish AD-M-79-160.srt
# Spanish AD-M-76-42.srt
# Spanish AD-M-76-194.srt
# Spanish AD-M-78-24.srt
# Spanish AD-M-79-13.srt
# Spanish AD-M-80-159.srt
# Spanish AD-M-79-184.srt
# Spanish AD-M-72-314.srt
# Spanish AD-M-78-155.srt
# Spanish AD-M-80-242.srt
# Spanish AD-M-81-193.srt
# Spanish AD-M-84-320.srt
# Spanish AD-M-82-321.srt
# Spanish AD-M-80-234.srt
# Spanish AD-M-84-313.srt
# Spanish AD-M-86-210.srt
# Spanish AD-M-80-316.srt
# Spanish AD-M-87-57.srt
# Spanish AD-M-81-280.srt
# Spanish AD-M-87-324.srt
# Spanish AD-W-59-49.srt
# Spanish AD-M-90-315.srt
# Spanish AD-W-62-45.srt
# Spanish AD-W-66-41.srt
# Spanish AD-W-67-157.srt
# Spanish AD-M-87-156.srt
# Spanish AD-M-89-281.srt
# Spanish AD-W-70-224.srt
# Spanish AD-W-76-225.srt
# Spanish AD-W-73-51.srt
# Spanish AD-W-77-162.srt
# Spanish AD-W-72-250.srt
# Spanish AD-W-76-317.srt
# Spanish AD-W-70-227.srt
# Spanish AD-W-71-47.srt
# Spanish AD-W-72-226.srt
# Spanish AD-W-77-52.srt
# Spanish AD-W-77-269.srt
# Spanish AD-W-77-319.srt
# Spanish AD-W-82-195.srt
# Spanish AD-W-81-246.srt
# Spanish AD-W-78-223.srt
# Spanish AD-W-80-202.srt
# Spanish AD-W-80-46.srt
# Spanish AD-W-80-310.srt
# Spanish AD-W-79-322.srt
# Spanish AD-W-84-318.srt
# Spanish AD-W-81-182.srt
# Spanish AD-W-84-183.srt
# Spanish AD-W-84-19.srt
# Spanish AD-W-83-247.srt
# Spanish AD-W-85-249.srt
# Spanish AD-W-84-283.srt
# Spanish AD-W-82-196.srt
# Spanish AD-W-82-282.srt
# Spanish AD-W-86-245.srt
# Spanish AD-W-86-284.srt
# Spanish AD-W-87-161.srt
# Spanish AD-M-72-44.srt
# Spanish AD-W-93-207.srt
# Spanish AD-W-89-237.srt
# Spanish AD-W-95-21.srt
# Spanish AD-W-87-244.srt
# Spanish AD-W-89-20.srt
# German FTD03.srt
# German FTD01.srt
# German FTD02.srt
# German FTD04.srt
# German Park_MCI04.srt
# German Park_Dement01.srt
# German Park_MCI01.srt
# German PPA_LPA.srt
# German PPA_PnfA.srt
# German Park_MCI03.srt
# German Park_Dement03.srt
# German Park_MCI02.srt
# German Park_Dement02.srt
